# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
import requests
from weatherbit.api import Api
import warnings

# %%
italia = pd.read_csv('2020_IT_Region_Mobility_Report.csv')

# %%
italia['date'] = pd.to_datetime(italia['date'])

# %%
italia['weekday'] = pd.to_datetime(italia['date']).dt.weekday

# %%
italia.drop(columns = ['country_region_code', 'country_region', 'metro_area', 'iso_3166_2_code', 'census_fips_code'], inplace = True )

# %%
italia[['retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 'parks_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']].corr()
# Out:
#                                                     retail_and_recreation_percent_change_from_baseline  \
# retail_and_recreation_percent_change_from_baseline                                           1.000000
# grocery_and_pharmacy_percent_change_from_baseline                                            0.875174
# parks_percent_change_from_baseline                                                           0.789355
# transit_stations_percent_change_from_baseline                                                0.881041
# workplaces_percent_change_from_baseline                                                      0.717346
# residential_percent_change_from_baseline                                                    -0.882204
#
#                                                     grocery_and_pharmacy_percent_change_from_baseline  \
# retail_and_recreation_percent_change_from_baseline                                           0.875174
# grocery_and_pharmacy_percent_change_from_baseline                                            1.000000
# parks_percent_change_from_baseline                                                           0.623214
# transit_stations_percent_change_from_baseline                                                0.750241
# workplaces_percent_change_from_baseline                                                      0.644576
# residential_percent_change_from_baseline                                                    -0.710166
#
#                                                     parks_percent_change_from_baseline  \
# retail_and_recreation_percent_change_from_baseline                            0.789355
# grocery_and_pharmacy_percent_change_from_baseline                             0.623214
# parks_percent_change_from_baseline                                            1.000000
# transit_stations_percent_change_from_baseline                                 0.774017
# workplaces_percent_change_from_baseline                                       0.469219
# residential_percent_change_from_baseline                                     -0.675462
#
#                                                     transit_stations_percent_change_from_baseline  \
# retail_and_recreation_percent_change_from_baseline                                       0.881041
# grocery_and_pharmacy_percent_change_from_baseline                                        0.750241
# parks_percent_change_from_baseline                                                       0.774017
# transit_stations_percent_change_from_baseline                                            1.000000
# workplaces_percent_change_from_baseline                                                  0.740720
# residential_percent_change_from_baseline                                                -0.827617
#
#                                                     workplaces_percent_change_from_baseline  \
# retail_and_recreation_percent_change_from_baseline                                 0.717346
# grocery_and_pharmacy_percent_change_from_baseline                                  0.644576
# parks_percent_change_from_baseline                                                 0.469219
# transit_stations_percent_change_from_baseline                                      0.740720
# workplaces_percent_change_from_baseline                                            1.000000
# residential_percent_change_from_baseline                                          -0.857449
#
#                                                     residential_percent_change_from_baseline
# retail_and_recreation_percent_change_from_baseline                                 -0.882204
# grocery_and_pharmacy_percent_change_from_baseline                                  -0.710166
# parks_percent_change_from_baseline                                                 -0.675462
# transit_stations_percent_change_from_baseline                                      -0.827617
# workplaces_percent_change_from_baseline                                            -0.857449
# residential_percent_change_from_baseline                                            1.000000

# %%
# National: clustering showing seasonality due to variable 'parks'.

model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,10))

visualizer.fit(italia[['retail_and_recreation_percent_change_from_baseline', 
                       'grocery_and_pharmacy_percent_change_from_baseline', 
                       'parks_percent_change_from_baseline', 
                       'transit_stations_percent_change_from_baseline', 
                       'workplaces_percent_change_from_baseline', 
                       'residential_percent_change_from_baseline']][(italia['sub_region_1'] != italia['sub_region_1'])])        
visualizer.show()

# %%
# National: clustering showing only the cut between 'lockdown' and 'non-lockdown' periods - variable 'parks' excluded.

model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,10))

visualizer.fit(italia[['retail_and_recreation_percent_change_from_baseline',
                       'grocery_and_pharmacy_percent_change_from_baseline',
                       'transit_stations_percent_change_from_baseline',
                       'workplaces_percent_change_from_baseline',
                       'residential_percent_change_from_baseline']][(italia['sub_region_1'] != italia['sub_region_1'])])        
visualizer.show()

# %%
# National, weekdays: clustering 'retail' vs 'parks' - variation including season and lockdown.

model = KMeans(n_clusters= 4)

X_n_w = italia[['date', 'retail_and_recreation_percent_change_from_baseline',
                'parks_percent_change_from_baseline']][(italia['sub_region_1'] != italia['sub_region_1'])&(italia['weekday'].isin (range(5)))]

model.fit(X_n_w[['retail_and_recreation_percent_change_from_baseline',
                'parks_percent_change_from_baseline']])
X_n_w['cluster'] = model.predict(X_n_w[['retail_and_recreation_percent_change_from_baseline',
                'parks_percent_change_from_baseline']])

# %%
# National, weekdays: looking for patterns of seasonality

X_n_w.groupby(by= 'cluster').mean()
# Out:
#          retail_and_recreation_percent_change_from_baseline  \
# cluster
# 0                                               -23.831579
# 1                                               -76.755556
# 2                                                 0.285714
# 3                                                -6.561404
#
#          parks_percent_change_from_baseline
# cluster
# 0                                 -1.305263
# 1                                -67.466667
# 2                                167.214286
# 3                                 76.964912

# %%
# National, weekend: clustering 'retail' vs 'parks' - variation including season and lockdown.

model = KMeans(n_clusters= 4)

X_n_e = italia[['date', 'retail_and_recreation_percent_change_from_baseline',
                'parks_percent_change_from_baseline']][(italia['sub_region_1'] != italia['sub_region_1'])&(italia['weekday'].isin ([5,6]))]

model.fit(X_n_e[['retail_and_recreation_percent_change_from_baseline',
                'parks_percent_change_from_baseline']])
X_n_e['cluster'] = model.predict(X_n_e[['retail_and_recreation_percent_change_from_baseline',
                'parks_percent_change_from_baseline']])

# %%
# National, weekends: looking for patterns of seasonality

X_n_e.groupby(by= 'cluster').mean()
# Out:
#          retail_and_recreation_percent_change_from_baseline  \
# cluster
# 0                                               -20.857143
# 1                                               -89.500000
# 2                                               -14.730769
# 3                                               -52.250000
#
#          parks_percent_change_from_baseline
# cluster
# 0                                 17.178571
# 1                                -83.937500
# 2                                 77.230769
# 3                                -31.687500

# %%
# National level DataFrame

italia_n = italia[(italia['sub_region_1'] != italia['sub_region_1'])]
italia_n.drop(italia[['sub_region_1', 'sub_region_2']], axis = 1, inplace = True)
italia_n
# Out:
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           date  retail_and_recreation_percent_change_from_baseline  \
# 0   2020-02-15                                                3.0
# 1   2020-02-16                                                3.0
# 2   2020-02-17                                                0.0
# 3   2020-02-18                                                3.0
# 4   2020-02-19                                                0.0
# ..         ...                                                ...
# 292 2020-12-03                                              -35.0
# 293 2020-12-04                                              -38.0
# 294 2020-12-05                                              -44.0
# 295 2020-12-06                                              -56.0
# 296 2020-12-07                                              -21.0
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                 -1.0
# 1                                                  2.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                 -1.0
# ..                                                 ...
# 292                                               -4.0
# 293                                               -6.0
# 294                                               -9.0
# 295                                              -30.0
# 296                                               10.0
#
#      parks_percent_change_from_baseline  \
# 0                                  35.0
# 1                                  26.0
# 2                                   7.0
# 3                                  16.0
# 4                                  11.0
# ..                                  ...
# 292                               -32.0
# 293                               -38.0
# 294                               -44.0
# 295                               -58.0
# 296                               -13.0
#
#      transit_stations_percent_change_from_baseline  \
# 0                                              9.0
# 1                                             11.0
# 2                                              3.0
# 3                                              4.0
# 4                                              3.0
# ..                                             ...
# 292                                          -44.0
# 293                                          -45.0
# 294                                          -48.0
# 295                                          -55.0
# 296                                          -46.0
#
#      workplaces_percent_change_from_baseline  \
# 0                                        0.0
# 1                                        1.0
# 2                                        1.0
# 3                                        1.0
# 4                                        1.0
# ..                                       ...
# 292                                    -27.0
# 293                                    -28.0
# 294                                    -26.0
# 295                                    -24.0
# 296                                    -45.0
#
#      residential_percent_change_from_baseline  weekday
# 0                                        -1.0        5
# 1                                        -2.0        6
# 2                                         0.0        0
# 3                                         0.0        1
# 4                                         0.0        2
# ..                                        ...      ...
# 292                                      14.0        3
# 293                                      15.0        4
# 294                                      14.0        5
# 295                                      14.0        6
# 296                                      15.0        0
#
# [297 rows x 8 columns]

# %%
plt.scatter(X_n_e['parks_percent_change_from_baseline'],X_n_e['retail_and_recreation_percent_change_from_baseline'], s = 40, c =X_n_e['cluster'], cmap='tab10' );

# %%
plt.scatter(X_n_w['parks_percent_change_from_baseline'],X_n_w['retail_and_recreation_percent_change_from_baseline'], s = 40, c =X_n_w['cluster'], cmap='tab10' );

# %%
model = KMeans(n_clusters= 4)

X_n = italia_n[['date', 'retail_and_recreation_percent_change_from_baseline',
                'parks_percent_change_from_baseline']]
model.fit(X_n[['retail_and_recreation_percent_change_from_baseline',
                'parks_percent_change_from_baseline']])
X_n['cluster'] = model.predict(X_n[['retail_and_recreation_percent_change_from_baseline',
                'parks_percent_change_from_baseline']])
# Out:
# <ipython-input-16-c8c589eb9540>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_n['cluster'] = model.predict(X_n[['retail_and_recreation_percent_change_from_baseline',

# %%
italia_n['status_code'] = X_n['cluster']
# Out:
# <ipython-input-17-811c5f2b4bb3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italia_n['status_code'] = X_n['cluster']

# %%
italia_n[['retail_and_recreation_percent_change_from_baseline','status_code']].groupby(by = 'status_code').mean()
# Out:
#              retail_and_recreation_percent_change_from_baseline
# status_code
# 0                                                    -8.906977
# 1                                                   -24.484127
# 2                                                   -77.700000
# 3                                                    -2.200000

# %%
mean_list = []
code_dict = {}
equiv_dict = {}

for i in range(4):
    mean_list.append(italia_n['retail_and_recreation_percent_change_from_baseline'][italia_n['status_code'] == i].mean() +
                    italia_n['parks_percent_change_from_baseline'][italia_n['status_code'] == i].mean())
    code_dict.update({i:italia_n['retail_and_recreation_percent_change_from_baseline'][italia_n['status_code'] == i].mean() +
                    italia_n['parks_percent_change_from_baseline'][italia_n['status_code'] == i].mean()})


mean_list = sorted(mean_list)
zip_eq = zip(mean_list, [i for i in range(4)])
equiv_dict = dict(zip_eq)

for i in mean_list:
    for j in code_dict.items():
        if j[1] == i:
            italia_n.loc[italia_n['status_code'] == j[0], 'status_code_2'] = int(equiv_dict[i])
            
italia_n['status_code'] = italia_n['status_code_2'].astype('int64')
italia_n.drop(columns = 'status_code_2', inplace = True)
# Out:
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-19-f087931a7f03>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italia_n['status_code'] = italia_n['status_code_2'].astype('int64')
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
fig, ax = plt.subplots(figsize=(56,16))


sns.barplot(ax = ax, x = italia_n['date'], y = italia_n['retail_and_recreation_percent_change_from_baseline'], hue = italia_n['status_code'])

# 22th. Febraury, lockdown in northern Italy
plt.axvline(7, -96.000000,5.000000, color = 'black')
# 8th. March ampliation of lockdown
plt.axvline(22, -96.000000,5.000000, color = 'black')
# 4th. May, restitution of freedom of movement
plt.axvline(79, -96.000000,5.000000, color = 'black')
# 3rd. June, inter-regional freedom of movement
plt.axvline(109, -96.000000,5.000000, color = 'black')
# 14th. October, peak of new cases
plt.axvline(242, -96.000000,5.000000, color = 'black')
# 11th November, national lockdown
plt.axvline(263, -96.000000,5.000000, color = 'black');


'''
plt.savefig(, dpi)
'''
# Out:
# '\nplt.savefig(, dpi)\n'

# %%
italia_n.iloc[[85,86],:]
# Out:
#          date  retail_and_recreation_percent_change_from_baseline  \
# 85 2020-05-10                                              -74.0
# 86 2020-05-11                                              -58.0
#
#     grocery_and_pharmacy_percent_change_from_baseline  \
# 85                                              -61.0
# 86                                              -31.0
#
#     parks_percent_change_from_baseline  \
# 85                               -43.0
# 86                               -45.0
#
#     transit_stations_percent_change_from_baseline  \
# 85                                          -57.0
# 86                                          -61.0
#
#     workplaces_percent_change_from_baseline  \
# 85                                    -28.0
# 86                                    -43.0
#
#     residential_percent_change_from_baseline  weekday  status_code
# 85                                      13.0        6            0
# 86                                      19.0        0            0

# %%
dates_list= []

for i in range(0,8):
    
    dates_list.append(italia_n.iloc[i, 0])
for i in range(109,263):
    
    dates_list.append(italia_n.iloc[i, 0])

# %%
italia_s = italia_n[italia_n['date'].isin(dates_list)]

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,10))

visualizer.fit(italia_s[['parks_percent_change_from_baseline']])
visualizer.show()

# %%
model = KMeans(n_clusters= 4)

X_s = italia_s[['parks_percent_change_from_baseline']]
model.fit(X_s[['parks_percent_change_from_baseline']])
X_s['cluster'] = model.predict(X_s[['parks_percent_change_from_baseline']])
# Out:
# <ipython-input-25-9877f11fb23b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_s['cluster'] = model.predict(X_s[['parks_percent_change_from_baseline']])

# %%
italia_s['season_code'] = X_s['cluster']
# Out:
# <ipython-input-26-157f91578b1e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italia_s['season_code'] = X_s['cluster']

# %%
italia_s[['season_code', 'parks_percent_change_from_baseline']].groupby(by= 'season_code').mean()
# Out:
#              parks_percent_change_from_baseline
# season_code
# 0                                     12.343750
# 1                                     99.424242
# 2                                     62.584906
# 3                                    174.500000

# %%
mean_list_s = []
code_dict_s = {}
equiv_dict_s = {}

for i in range(4):
    mean_list_s.append(italia_s['parks_percent_change_from_baseline'][italia_s['season_code'] == i].mean())
    code_dict_s.update({i:italia_s['parks_percent_change_from_baseline'][italia_s['season_code'] == i].mean()})


mean_list_s = sorted(mean_list_s)
zip_eq_s = zip(mean_list_s, [i for i in range(4)])
equiv_dict_s = dict(zip_eq_s)

for i in mean_list_s:
    for j in code_dict_s.items():
        if j[1] == i:
            italia_s.loc[italia_s['season_code'] == j[0], 'season_code_2'] = int(equiv_dict_s[i])
            
italia_s['season_code'] = italia_s['season_code_2'].astype('int64')
italia_s.drop(columns = 'season_code_2', inplace = True)
# Out:
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-28-0df833b5f7cd>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italia_s['season_code'] = italia_s['season_code_2'].astype('int64')
# C:\Users\Microsoft\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
italia_s[['date', 
          'parks_percent_change_from_baseline',
          'weekday']][(italia_s['season_code'] == 0)&(italia['weekday'].isin([5,6]))]
# Out:
# <ipython-input-29-7e900b90260a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   italia_s[['date',
#           date  parks_percent_change_from_baseline  weekday
# 0   2020-02-15                                35.0        5
# 1   2020-02-16                                26.0        6
# 7   2020-02-22                                30.0        5
# 112 2020-06-06                                31.0        5
# 113 2020-06-07                                -4.0        6
# 119 2020-06-13                                29.0        5
# 120 2020-06-14                                30.0        6
# 224 2020-09-26                                31.0        5
# 225 2020-09-27                                -3.0        6
# 231 2020-10-03                                13.0        5
# 232 2020-10-04                                11.0        6
# 239 2020-10-11                               -19.0        6
# 245 2020-10-17                                22.0        5
# 246 2020-10-18                                20.0        6
# 252 2020-10-24                                -6.0        5
# 253 2020-10-25                                 5.0        6
# 259 2020-10-31                                12.0        5
# 260 2020-11-01                                -3.0        6

# %%
italia_s[['date', 
          'parks_percent_change_from_baseline',
          'weekday']][(italia_s['season_code'] == 0)&(italia['weekday'].isin([0,1,2,3,4]))]
# Out:
# <ipython-input-30-788075f63245>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   italia_s[['date',
#           date  parks_percent_change_from_baseline  weekday
# 2   2020-02-17                                 7.0        0
# 3   2020-02-18                                16.0        1
# 4   2020-02-19                                11.0        2
# 5   2020-02-20                                18.0        3
# 6   2020-02-21                                19.0        4
# 109 2020-06-03                                 6.0        2
# 110 2020-06-04                               -24.0        3
# 111 2020-06-05                                 1.0        4
# 114 2020-06-08                                -7.0        0
# 115 2020-06-09                                 9.0        1
# 116 2020-06-10                                 2.0        2
# 117 2020-06-11                                 3.0        3
# 118 2020-06-12                                35.0        4
# 121 2020-06-15                                19.0        0
# 122 2020-06-16                                27.0        1
# 123 2020-06-17                                24.0        2
# 124 2020-06-18                                36.0        3
# 220 2020-09-22                                32.0        1
# 221 2020-09-23                                33.0        2
# 222 2020-09-24                                29.0        3
# 223 2020-09-25                                13.0        4
# 226 2020-09-28                                19.0        0
# 229 2020-10-01                                25.0        3
# 230 2020-10-02                                 8.0        4
# 233 2020-10-05                                19.0        0
# 234 2020-10-06                                27.0        1
# 235 2020-10-07                                20.0        2
# 236 2020-10-08                                30.0        3
# 237 2020-10-09                                30.0        4
# 240 2020-10-12                                 4.0        0
# 241 2020-10-13                                20.0        1
# 242 2020-10-14                                 5.0        2
# 243 2020-10-15                               -17.0        3
# 244 2020-10-16                                 6.0        4
# 247 2020-10-19                                11.0        0
# 248 2020-10-20                                14.0        1
# 249 2020-10-21                                12.0        2
# 250 2020-10-22                                 5.0        3
# 251 2020-10-23                                -7.0        4
# 254 2020-10-26                               -14.0        0
# 255 2020-10-27                                 1.0        1
# 256 2020-10-28                                 7.0        2
# 257 2020-10-29                                -1.0        3
# 258 2020-10-30                                 2.0        4
# 261 2020-11-02                                -1.0        0
# 262 2020-11-03                                -4.0        1

# %%
italia_s[['date', 
          'parks_percent_change_from_baseline',
          'weekday']][(italia_s['season_code'] == 0)].head(10)
# Out:
#           date  parks_percent_change_from_baseline  weekday
# 0   2020-02-15                                35.0        5
# 1   2020-02-16                                26.0        6
# 2   2020-02-17                                 7.0        0
# 3   2020-02-18                                16.0        1
# 4   2020-02-19                                11.0        2
# 5   2020-02-20                                18.0        3
# 6   2020-02-21                                19.0        4
# 7   2020-02-22                                30.0        5
# 109 2020-06-03                                 6.0        2
# 110 2020-06-04                               -24.0        3

# %%
italia_s[['date', 
          'parks_percent_change_from_baseline',
          'retail_and_recreation_percent_change_from_baseline',
          'weekday']][(italia_s['season_code'] == 0)].tail(50)
# Out:
#           date  parks_percent_change_from_baseline  \
# 115 2020-06-09                                 9.0
# 116 2020-06-10                                 2.0
# 117 2020-06-11                                 3.0
# 118 2020-06-12                                35.0
# 119 2020-06-13                                29.0
# 120 2020-06-14                                30.0
# 121 2020-06-15                                19.0
# 122 2020-06-16                                27.0
# 123 2020-06-17                                24.0
# 124 2020-06-18                                36.0
# 220 2020-09-22                                32.0
# 221 2020-09-23                                33.0
# 222 2020-09-24                                29.0
# 223 2020-09-25                                13.0
# 224 2020-09-26                                31.0
# 225 2020-09-27                                -3.0
# 226 2020-09-28                                19.0
# 229 2020-10-01                                25.0
# 230 2020-10-02                                 8.0
# 231 2020-10-03                                13.0
# 232 2020-10-04                                11.0
# 233 2020-10-05                                19.0
# 234 2020-10-06                                27.0
# 235 2020-10-07                                20.0
# 236 2020-10-08                                30.0
# 237 2020-10-09                                30.0
# 239 2020-10-11                               -19.0
# 240 2020-10-12                                 4.0
# 241 2020-10-13                                20.0
# 242 2020-10-14                                 5.0
# 243 2020-10-15                               -17.0
# 244 2020-10-16                                 6.0
# 245 2020-10-17                                22.0
# 246 2020-10-18                                20.0
# 247 2020-10-19                                11.0
# 248 2020-10-20                                14.0
# 249 2020-10-21                                12.0
# 250 2020-10-22                                 5.0
# 251 2020-10-23                                -7.0
# 252 2020-10-24                                -6.0
# 253 2020-10-25                                 5.0
# 254 2020-10-26                               -14.0
# 255 2020-10-27                                 1.0
# 256 2020-10-28                                 7.0
# 257 2020-10-29                                -1.0
# 258 2020-10-30                                 2.0
# 259 2020-10-31                                12.0
# 260 2020-11-01                                -3.0
# 261 2020-11-02                                -1.0
# 262 2020-11-03                                -4.0
#
#      retail_and_recreation_percent_change_from_baseline  weekday
# 115                                              -21.0         1
# 116                                              -23.0         2
# 117                                              -21.0         3
# 118                                              -19.0         4
# 119                                              -24.0         5
# 120                                              -23.0         6
# 121                                              -18.0         0
# 122                                              -16.0         1
# 123                                              -17.0         2
# 124                                              -15.0         3
# 220                                               -7.0         1
# 221                                               -9.0         2
# 222                                              -10.0         3
# 223                                              -14.0         4
# 224                                              -11.0         5
# 225                                              -20.0         6
# 226                                              -10.0         0
# 229                                               -9.0         3
# 230                                              -14.0         4
# 231                                              -13.0         5
# 232                                              -15.0         6
# 233                                              -11.0         0
# 234                                               -8.0         1
# 235                                              -12.0         2
# 236                                              -10.0         3
# 237                                              -11.0         4
# 239                                              -24.0         6
# 240                                              -15.0         0
# 241                                              -11.0         1
# 242                                              -15.0         2
# 243                                              -19.0         3
# 244                                              -16.0         4
# 245                                              -17.0         5
# 246                                              -20.0         6
# 247                                              -16.0         0
# 248                                              -15.0         1
# 249                                              -16.0         2
# 250                                              -17.0         3
# 251                                              -20.0         4
# 252                                              -25.0         5
# 253                                              -28.0         6
# 254                                              -26.0         0
# 255                                              -21.0         1
# 256                                              -23.0         2
# 257                                              -24.0         3
# 258                                              -26.0         4
# 259                                              -29.0         5
# 260                                              -38.0         6
# 261                                              -24.0         0
# 262                                              -24.0         1

# %%
# Post-lockdown: similar week

comparison_list = [229,230,231,232,233,234,235]

italia_s[['date','parks_percent_change_from_baseline', 'retail_and_recreation_percent_change_from_baseline', 'residential_percent_change_from_baseline', 'weekday']][italia_s.index.isin(comparison_list)]
# Out:
#           date  parks_percent_change_from_baseline  \
# 229 2020-10-01                                25.0
# 230 2020-10-02                                 8.0
# 231 2020-10-03                                13.0
# 232 2020-10-04                                11.0
# 233 2020-10-05                                19.0
# 234 2020-10-06                                27.0
# 235 2020-10-07                                20.0
#
#      retail_and_recreation_percent_change_from_baseline  \
# 229                                               -9.0
# 230                                              -14.0
# 231                                              -13.0
# 232                                              -15.0
# 233                                              -11.0
# 234                                               -8.0
# 235                                              -12.0
#
#      residential_percent_change_from_baseline  weekday
# 229                                       3.0        3
# 230                                       4.0        4
# 231                                       2.0        5
# 232                                       1.0        6
# 233                                       3.0        0
# 234                                       3.0        1
# 235                                       3.0        2

# %%
# Pre-lockdown: similar week

reference_list = [1,2,3,4,5,6,7]

italia_s[['date','parks_percent_change_from_baseline', 'retail_and_recreation_percent_change_from_baseline', 'residential_percent_change_from_baseline', 'weekday']][italia_s.index.isin(reference_list)]
# Out:
#         date  parks_percent_change_from_baseline  \
# 1 2020-02-16                                26.0
# 2 2020-02-17                                 7.0
# 3 2020-02-18                                16.0
# 4 2020-02-19                                11.0
# 5 2020-02-20                                18.0
# 6 2020-02-21                                19.0
# 7 2020-02-22                                30.0
#
#    retail_and_recreation_percent_change_from_baseline  \
# 1                                                3.0
# 2                                                0.0
# 3                                                3.0
# 4                                                0.0
# 5                                                2.0
# 6                                                1.0
# 7                                               -1.0
#
#    residential_percent_change_from_baseline  weekday
# 1                                      -2.0        6
# 2                                       0.0        0
# 3                                       0.0        1
# 4                                       0.0        2
# 5                                       0.0        3
# 6                                      -1.0        4
# 7                                      -1.0        5

# %%
# Baseline-comparable week

bl_comparable = [255, 256, 257, 258, 259, 260, 260, 261]

italia_s[['date','parks_percent_change_from_baseline', 'retail_and_recreation_percent_change_from_baseline', 'residential_percent_change_from_baseline', 'weekday']][italia_s.index.isin(bl_comparable)]
# Out:
#           date  parks_percent_change_from_baseline  \
# 255 2020-10-27                                 1.0
# 256 2020-10-28                                 7.0
# 257 2020-10-29                                -1.0
# 258 2020-10-30                                 2.0
# 259 2020-10-31                                12.0
# 260 2020-11-01                                -3.0
# 261 2020-11-02                                -1.0
#
#      retail_and_recreation_percent_change_from_baseline  \
# 255                                              -21.0
# 256                                              -23.0
# 257                                              -24.0
# 258                                              -26.0
# 259                                              -29.0
# 260                                              -38.0
# 261                                              -24.0
#
#      residential_percent_change_from_baseline  weekday
# 255                                       9.0        1
# 256                                       9.0        2
# 257                                      10.0        3
# 258                                      10.0        4
# 259                                       7.0        5
# 260                                       7.0        6
# 261                                      10.0        0

# %%
api_key = "e2b62675291d4c93aabcd1ed9ae3923b"
api = Api(api_key)

# %%
api.set_granularity('daily')

# %%
avg_temp_r_f = []

for i in range(16,23):
    history = api.get_history(city = 'Rome', start_date= f'2020-02-{i}',end_date=f'2020-02-{i+1}')
    avg_temp_r_f.append(history.json['data'][0]['temp'])

# %%
avg_temp_r_o1 = []

for i in range(1,8):
    history = api.get_history(city = 'Rome', start_date= f'2020-10-{i}',end_date=f'2020-10-{i+1}')
    avg_temp_r_o1.append(history.json['data'][0]['temp'])

# %%
avg_temp_r_o2 = []

for i in range(27,31):
    history = api.get_history(city = 'Rome', start_date= f'2020-10-{i}',end_date=f'2020-10-{i+1}')
    avg_temp_r_o2.append(history.json['data'][0]['temp'])

history = api.get_history(city = 'Rome', start_date= f'2020-10-31',end_date=f'2020-11-1')
avg_temp_r_o2.append(history.json['data'][0]['temp'])

for i in range(1,3):
    history = api.get_history(city = 'Rome', start_date= f'2020-11-{i}',end_date=f'2020-11-{i+1}')
    avg_temp_r_o2.append(history.json['data'][0]['temp'])

# %%
print(avg_temp_r_f)
print(avg_temp_r_o1)
print(avg_temp_r_o2)
# Out:
# [10.1, 9.8, 10.4, 9.9, 9.5, 9, 10.4]
# [17.3, 19.8, 20.3, 18, 18.4, 17.3, 18.2]
# [15.3, 12.9, 13.1, 13.9, 14.2, 15, 15.2]

# %%
avg_temp_n_f = []

for i in range(16,23):
    history = api.get_history(city = 'Naples', start_date= f'2020-02-{i}',end_date=f'2020-02-{i+1}')
    avg_temp_n_f.append(history.json['data'][0]['temp'])

# %%
avg_temp_n_o1 = []

for i in range(1,8):
    history = api.get_history(city = 'Naples', start_date= f'2020-10-{i}',end_date=f'2020-10-{i+1}')
    avg_temp_n_o1.append(history.json['data'][0]['temp'])

# %%
avg_temp_n_o2 = []

for i in range(27,31):
    history = api.get_history(city = 'Naples', start_date= f'2020-10-{i}',end_date=f'2020-10-{i+1}')
    avg_temp_n_o2.append(history.json['data'][0]['temp'])

history = api.get_history(city = 'Naples', start_date= f'2020-10-31',end_date=f'2020-11-1')
avg_temp_n_o2.append(history.json['data'][0]['temp'])

for i in range(1,3):
    history = api.get_history(city = 'Naples', start_date= f'2020-11-{i}',end_date=f'2020-11-{i+1}')
    avg_temp_n_o2.append(history.json['data'][0]['temp'])

# %%
print(avg_temp_n_f)
print(avg_temp_n_o1)
print(avg_temp_n_o2)
# Out:
# [10.6, 9.8, 11.1, 11.7, 9.9, 9.7, 11.4]
# [18, 18.6, 22.1, 19.3, 18.9, 18.1, 17.4]
# [15.5, 14.3, 14.3, 15.7, 15.1, 16.1, 15.5]

# %%
avg_temp_m_f = []

for i in range(16,23):
    history = api.get_history(city = 'Milan', country = 'Italy', start_date= f'2020-02-{i}',end_date=f'2020-02-{i+1}')
    avg_temp_m_f.append(history.json['data'][0]['temp'])

# %%
avg_temp_m_f
# Out:
# [7.7, 9.7, 10.1, 8.2, 7.4, 7.7, 8.1]

# %%
avg_temp_m_o1 = []

for i in range(1,8):
    history = api.get_history(city = 'Milan', country = 'Italy', start_date= f'2020-10-{i}',end_date=f'2020-10-{i+1}')
    avg_temp_m_o1.append(history.json['data'][0]['temp'])

# %%
avg_temp_m_o2 = []

for i in range(27,31):
    history = api.get_history(city = 'Milan', country ='Italy', start_date= f'2020-10-{i}',end_date=f'2020-10-{i+1}')
    avg_temp_m_o2.append(history.json['data'][0]['temp'])

history = api.get_history(city = 'Milan', country ='Italy', start_date= f'2020-10-31',end_date=f'2020-11-1')
avg_temp_m_o2.append(history.json['data'][0]['temp'])

for i in range(1,3):
    history = api.get_history(city = 'Milan', country ='Italy', start_date= f'2020-11-{i}',end_date=f'2020-11-{i+1}')
    avg_temp_m_o2.append(history.json['data'][0]['temp'])

# %%
print(avg_temp_n_f)
print(avg_temp_n_o1)
print(avg_temp_n_o2)
# Out:
# [10.6, 9.8, 11.1, 11.7, 9.9, 9.7, 11.4]
# [18, 18.6, 22.1, 19.3, 18.9, 18.1, 17.4]
# [15.5, 14.3, 14.3, 15.7, 15.1, 16.1, 15.5]
